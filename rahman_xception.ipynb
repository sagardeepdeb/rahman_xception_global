# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import os
import numpy as np
np.random.seed(777)
import math
import keras
import keras.backend as K
import h5py
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD, RMSprop
from keras.models import Sequential
from keras.models import Model
from keras.layers import Input, Activation, merge, Dense, Flatten, Dropout, concatenate
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, add, GlobalAveragePooling2D
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score
from keras.regularizers import l2
from keras.applications.xception import Xception, preprocess_input
from keras.applications.mobilenet import MobileNet
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications import DenseNet201
from keras.applications import DenseNet121

from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, Lambda,Concatenate
from keras.layers import SeparableConv2D, AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D, Add

import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 20})

# %%
train_dir = '/content/drive/My Drive/DDSM_CBIS_Enhanced/train/'
test_dir = '/content/drive/My Drive/DDSM_CBIS_Enhanced/test/'
valid_dir = '/content/drive/My Drive/DDSM_CBIS_Enhanced/valid/'

extracted_features_dir = '/content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/'
model_name = "Rahman_Xcep"

# %%
import keras
import tensorflow as tf
import keras.backend as K

print("Keras Version", keras.__version__)
print("tensorflow Version", tf.__version__)
# Out:
# Keras Version 2.4.3
# tensorflow Version 2.3.0

# %%
batch_size = 32
img_height, img_width = 224, 224
input_shape = (img_height, img_width, 3)
epochs = 1000

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))

print("*"*30)
for root,dirs,files in os.walk(test_dir):
    print (root, len(files))

print("*"*30)
for root,dirs,files in os.walk(valid_dir):
    print (root, len(files))
# Out:
# /content/drive/My Drive/DDSM_CBIS_Enhanced/train/ 0
# /content/drive/My Drive/DDSM_CBIS_Enhanced/train/benign 572
# /content/drive/My Drive/DDSM_CBIS_Enhanced/train/malignant 522
# ******************************
# /content/drive/My Drive/DDSM_CBIS_Enhanced/test/ 0
# /content/drive/My Drive/DDSM_CBIS_Enhanced/test/malignant 147
# /content/drive/My Drive/DDSM_CBIS_Enhanced/test/benign 230
# ******************************
# /content/drive/My Drive/DDSM_CBIS_Enhanced/valid/ 0
# /content/drive/My Drive/DDSM_CBIS_Enhanced/valid/benign 101
# /content/drive/My Drive/DDSM_CBIS_Enhanced/valid/malignant 100

# %%
random_seed = np.random.seed(1142)

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    validation_split= 0.25,
    zoom_range=0.2,
    shear_range=0.2)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'training',
    class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(
    valid_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'validation',
    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    class_mode='categorical')
# Out:
# Found 821 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# Found 377 images belonging to 2 classes.

# %%
nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
predict_size_train = int(math.ceil(nb_train_samples / batch_size))
predict_size_validation = int(math.ceil(nb_validation_samples / batch_size))

nb_test_samples = len(test_generator.filenames)
predict_size_test = int(math.ceil(nb_test_samples / batch_size))

# nb_test_without_aug_samples = len(test_generator_without_aug.filenames)
# predict_size_test_without_aug = int(math.ceil(nb_test_without_aug_samples / batch_size))

num_classes = len(train_generator.class_indices)

print("nb_train_samples:", nb_train_samples)
print("nb_validation_samples:", nb_validation_samples)
print("\npredict_size_train:", predict_size_train)
print("predict_size_validation:", predict_size_validation)
# print("nb_test_without_aug_samples:", nb_test_without_aug_samples)
# print("predict_size_test_without_aug_samples:", predict_size_test_without_aug)
print("nb_test_samples:", nb_test_samples)
print("predict_size_test:", predict_size_test)

print("\n num_classes:", num_classes)
# Out:
# nb_train_samples: 821
# nb_validation_samples: 50
#
# predict_size_train: 26
# predict_size_validation: 2
# nb_test_samples: 377
# predict_size_test: 12
#
#  num_classes: 2

# %%
# from keras.applications.mobilenetv2 import MobileNetV2
# from keras.applications.densenet import DenseNet169
# from keras.applications.vgg19 import VGG19
from keras.applications.inception_v3 import InceptionV3
# from keras.applications.vgg16 import VGG16
from keras.applications.xception import Xception, preprocess_input
# from keras.applications import DenseNet201
# from keras.applications import DenseNet121
# from keras.applications import ResNet50
from keras.applications.inception_resnet_v2 import InceptionResNetV2
# from keras.applications import NASNetLarge, NASNetMobile
# from keras.applications import MobileNet


input_tensor = Input(shape = input_shape)  
model = Xception(weights='imagenet', include_top=False, pooling = 'avg', input_tensor=input_tensor)
bottleneck_final_model = model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step

# %%
bottleneck_features_train = bottleneck_final_model.predict_generator(train_generator, predict_size_train)
np.save(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy', bottleneck_features_train)
# Out:
# WARNING:tensorflow:From <ipython-input-10-8f58c074c945>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
bottleneck_features_validation = bottleneck_final_model.predict_generator(validation_generator, predict_size_validation)
np.save(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy', bottleneck_features_validation)

# %%
bottleneck_features_test = bottleneck_final_model.predict_generator(test_generator, predict_size_test)
np.save(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy', bottleneck_features_test)

# %%
train_data = np.load(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy')
validation_data = np.load(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy')
test_data = np.load(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy')

train_labels = train_generator.classes
train_labels = to_categorical(train_labels, num_classes=num_classes)

validation_labels = validation_generator.classes
validation_labels = to_categorical(validation_labels, num_classes=num_classes)

test_labels = test_generator.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)

# %%
# example of saving sub-models for later use in a stacking ensemble
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot
import os , shutil
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint


stop = EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='min')
save = ModelCheckpoint('/content/drive/My Drive/Brain-Tumor-Detection-master/extracted/my_model.hdf5', save_best_only=True, monitor='val_loss', mode='min')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=50, verbose=1, epsilon=1e-3, mode='min')

 
# fit model on dataset
def fit_model(trainX,trainy):
  dropout_rate = 0.4
  model = Sequential()
  # model.add(Flatten(input_shape=train_data.shape[1:]))
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(num_classes, activation=tf.nn.softmax))
  adam_opt2=Adam(lr = 0.0001, beta_1=0.6, beta_2=0.9, amsgrad=False)
  model.compile(optimizer=adam_opt2, loss='categorical_crossentropy', metrics=['accuracy'])
  model.fit(trainX,trainy,epochs=500,validation_data=(validation_data, validation_labels),batch_size=batch_size,verbose=0,callbacks=[stop, save, reduce_lr])
  return model



trainX = train_data
testX  = test_data
trainy = train_generator.classes
trainy = to_categorical(trainy, num_classes=2)
testy  = test_generator.classes
testy_enc = to_categorical(testy, num_classes=2)


print(trainX.shape, trainy.shape)
print(testX.shape, testy.shape)
# create directory for models
base_dir = '/content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/'
#os.mkdir(base_dir)
# fit and save models
n_members = 5
for i in range(n_members):
	# fit model
	model = fit_model(trainX, trainy)
	# save model
	filename = '/content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_' + str(i + 1) + '.h5'
	model.save(filename)
	print('>Saved %s' % filename)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# (821, 2048) (821, 2)
# (377, 2048) (377,)
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 00073: early stopping
# >Saved /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_1.h5
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 00062: early stopping
# >Saved /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_2.h5
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 00073: early stopping
# >Saved /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_3.h5
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 00067: early stopping
# >Saved /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_4.h5
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 00067: early stopping
# >Saved /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_5.h5

# %%
# load models from file
from keras.models import load_model
from numpy import dstack
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from keras.models import load_model
from keras.utils import to_categorical
from numpy import dstack




def load_all_models(n_models):
	all_models = list()
	for i in range(n_models):
		# define filename for this ensemble
		filename = '/content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_' + str(i + 1) + '.h5'
		# load model from file
		model = load_model(filename)
		# add to list of members
		all_models.append(model)
		print('>loaded %s' % filename)
	return all_models

# %%
# load all models
members = load_all_models(n_members)
print('Loaded %d models' % len(members))
# Out:
# >loaded /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_1.h5
# >loaded /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_2.h5
# >loaded /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_3.h5
# >loaded /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_4.h5
# >loaded /content/drive/My Drive/DDSM_CBIS_Enhanced/extracted_features/model_5.h5
# Loaded 5 models

# %%
# evaluate standalone models on test dataset
for model in members:
	testy_enc = to_categorical(testy)
	_, acc = model.evaluate(testX, testy_enc, verbose=0)
	print('Model Accuracy: %.3f' % acc)
# Out:
# Model Accuracy: 0.692
# Model Accuracy: 0.719
# Model Accuracy: 0.692
# Model Accuracy: 0.687
# Model Accuracy: 0.698

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from keras.preprocessing.image import ImageDataGenerator, load_img

# %%
for model in members:
  preds = model.predict(test_data)

  predictions = [i.argmax() for i in preds]
  y_true = [i.argmax() for i in test_labels]
  cm = confusion_matrix(y_pred=predictions, y_true=y_true)

  print('Accuracy {}'.format(accuracy_score(y_true=y_true, y_pred=predictions)))
  plt.rcParams["axes.grid"] = False
  plt.rcParams.update({'font.size': 20})

  labels = []

  label = test_generator.class_indices
  indexlabel = dict((value, key) for key, value in label.items())

  for k,v in indexlabel.items():
      labels.append(v)

  from sklearn.metrics import confusion_matrix
  import itertools
  def plot_confusion_matrix(cm, classes,
                            normalize=False,
                            title='Confusion matrix',
                            cmap=plt.cm.Blues):
      accuracy = np.trace(cm) / float(np.sum(cm))
      misclass = 1 - accuracy
      if normalize:
          cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
          print("Normalized confusion matrix")
      else:
          print('Confusion Matrix')

      print(cm)
  #     fig = plt.figure()
      plt.imshow(cm, interpolation='nearest', cmap=cmap)
  #     plt.title(title)
  #     plt.colorbar()
      tick_marks = np.arange(len(classes))
      plt.xticks(tick_marks, classes, rotation=45)
      plt.yticks(tick_marks, classes)

      fmt = '.2f' if normalize else 'd'
      thresh = cm.max() / 2.
      for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, format(cm[i, j], fmt),
                   horizontalalignment="center",
                   color="white" if cm[i, j] > thresh else "black")

      plt.tight_layout()
      plt.ylabel('True label')
      plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
      #plt.savefig('/content/drive/My Drive/data_v3/extracted_features/confusion_marix.png', bbox_inches='tight', dpi = 100) 


  #plt.figure(figsize=(10,10))
  #plot_confusion_matrix(cm, classes=labels, title=' ')

  from sklearn.preprocessing import LabelEncoder
  from sklearn.metrics import confusion_matrix, classification_report
  y_pred=predictions
  y_pred_probabilities=y_pred

  # y_pred = np.argmax(y_pred,axis = 1) 
  y_actual = y_true

  classnames=[]
  for classname in test_generator.class_indices:
      classnames.append(classname)

  confusion_mtx = confusion_matrix(y_actual, y_pred) 
  print(confusion_mtx)
  target_names = classnames
  print(classification_report(y_actual, y_pred, target_names=target_names))



  from keras.preprocessing.image import ImageDataGenerator, load_img
  fnames = test_generator.filenames
  ground_truth = test_generator.classes

  label2index = test_generator.class_indices
  idx2label = dict((v,k) for k,v in label2index.items())

  predictions = model.predict(test_data)
  predicted_classes = np.argmax(predictions,axis=1)

  errors = np.where(predicted_classes != ground_truth)[0]
  no_error = len(errors)
  print("No of errors = {}/{}".format(len(errors),test_generator.samples))
  #no_errors.append(no_error)

  # Show the errors
  for i in range(len(errors)):
      pred_class = np.argmax(predictions[errors[i]])
      pred_label = idx2label[pred_class]

      title = 'filename:{},Original label:{}, Prediction :{}, confidence : {:.3f}, class ID : {}'.format(
              fnames[errors[i]],
              fnames[errors[i]].split('/')[0],
              pred_label,
              predictions[errors[i]][pred_class], pred_class)

      original = load_img('{}/{}'.format(test_dir,fnames[errors[i]]))
      #plt.figure(figsize=[7,7])
      #plt.axis('off')
      #plt.title(title)
      #plt.imshow(original)
      print(title)
  #plt.show()
# Out:
# Accuracy 0.6923076923076923
# [[171  59]
#  [ 57  90]]
#               precision    recall  f1-score   support
#
#       benign       0.75      0.74      0.75       230
#    malignant       0.60      0.61      0.61       147
#
#     accuracy                           0.69       377
#    macro avg       0.68      0.68      0.68       377
# weighted avg       0.69      0.69      0.69       377
#
# No of errors = 116/377
# filename:benign/Mass-Test_P_00032_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.806, class ID : 1
# filename:benign/Mass-Test_P_00126_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.586, class ID : 1
# filename:benign/Mass-Test_P_00126_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.507, class ID : 1
# filename:benign/Mass-Test_P_00131_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.525, class ID : 1
# filename:benign/Mass-Test_P_00159_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.630, class ID : 1
# filename:benign/Mass-Test_P_00173_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.802, class ID : 1
# filename:benign/Mass-Test_P_00173_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.652, class ID : 1
# filename:benign/Mass-Test_P_00200_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.770, class ID : 1
# filename:benign/Mass-Test_P_00203_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.562, class ID : 1
# filename:benign/Mass-Test_P_00238_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.523, class ID : 1
# filename:benign/Mass-Test_P_00358_RIGHT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.721, class ID : 1
# filename:benign/Mass-Test_P_00359_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.732, class ID : 1
# filename:benign/Mass-Test_P_00369_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.539, class ID : 1
# filename:benign/Mass-Test_P_00391_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.576, class ID : 1
# filename:benign/Mass-Test_P_00405_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.649, class ID : 1
# filename:benign/Mass-Test_P_00409_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.503, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.715, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.800, class ID : 1
# filename:benign/Mass-Test_P_00457_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.508, class ID : 1
# filename:benign/Mass-Test_P_00482_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.588, class ID : 1
# filename:benign/Mass-Test_P_00490_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.556, class ID : 1
# filename:benign/Mass-Test_P_00494_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.806, class ID : 1
# filename:benign/Mass-Test_P_00587_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.953, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.688, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.572, class ID : 1
# filename:benign/Mass-Test_P_00639_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.538, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.743, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.802, class ID : 1
# filename:benign/Mass-Test_P_00671_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.510, class ID : 1
# filename:benign/Mass-Test_P_00738_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.562, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.789, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.701, class ID : 1
# filename:benign/Mass-Test_P_00820_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.526, class ID : 1
# filename:benign/Mass-Test_P_00820_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.549, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.607, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.797, class ID : 1
# filename:benign/Mass-Test_P_00922_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.935, class ID : 1
# filename:benign/Mass-Test_P_00951_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.818, class ID : 1
# filename:benign/Mass-Test_P_00966_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.787, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.615, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.669, class ID : 1
# filename:benign/Mass-Test_P_01108_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.611, class ID : 1
# filename:benign/Mass-Test_P_01145_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.796, class ID : 1
# filename:benign/Mass-Test_P_01322_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.636, class ID : 1
# filename:benign/Mass-Test_P_01395_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.670, class ID : 1
# filename:benign/Mass-Test_P_01416_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.839, class ID : 1
# filename:benign/Mass-Test_P_01510_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.568, class ID : 1
# filename:benign/Mass-Test_P_01512_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.640, class ID : 1
# filename:benign/Mass-Test_P_01539_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.582, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.557, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.510, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_MLO_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.666, class ID : 1
# filename:benign/Mass-Test_P_01623_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.780, class ID : 1
# filename:benign/Mass-Test_P_01645_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.567, class ID : 1
# filename:benign/Mass-Test_P_01684_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.721, class ID : 1
# filename:benign/Mass-Test_P_01697_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.926, class ID : 1
# filename:benign/Mass-Test_P_01726_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.553, class ID : 1
# filename:benign/Mass-Test_P_01796_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.549, class ID : 1
# filename:benign/Mass-Test_P_01825_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.816, class ID : 1
# filename:malignant/Mass-Test_P_00017_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.860, class ID : 0
# filename:malignant/Mass-Test_P_00017_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.651, class ID : 0
# filename:malignant/Mass-Test_P_00066_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.526, class ID : 0
# filename:malignant/Mass-Test_P_00116_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.822, class ID : 0
# filename:malignant/Mass-Test_P_00118_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.853, class ID : 0
# filename:malignant/Mass-Test_P_00147_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.933, class ID : 0
# filename:malignant/Mass-Test_P_00194_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.890, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.730, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.720, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.707, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.870, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.573, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.948, class ID : 0
# filename:malignant/Mass-Test_P_00296_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.671, class ID : 0
# filename:malignant/Mass-Test_P_00324_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.627, class ID : 0
# filename:malignant/Mass-Test_P_00347_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.705, class ID : 0
# filename:malignant/Mass-Test_P_00481_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.635, class ID : 0
# filename:malignant/Mass-Test_P_00498_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.750, class ID : 0
# filename:malignant/Mass-Test_P_00514_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.718, class ID : 0
# filename:malignant/Mass-Test_P_00524_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.800, class ID : 0
# filename:malignant/Mass-Test_P_00576_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.666, class ID : 0
# filename:malignant/Mass-Test_P_00591_RIGHT_MLO_ROI_Mass_M_3.png .png,Original label:malignant, Prediction :benign, confidence : 0.983, class ID : 0
# filename:malignant/Mass-Test_P_00636_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.548, class ID : 0
# filename:malignant/Mass-Test_P_00677_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.583, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.764, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.737, class ID : 0
# filename:malignant/Mass-Test_P_00758_LEFT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.630, class ID : 0
# filename:malignant/Mass-Test_P_00773_LEFT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.725, class ID : 0
# filename:malignant/Mass-Test_P_00813_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.648, class ID : 0
# filename:malignant/Mass-Test_P_00820_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.595, class ID : 0
# filename:malignant/Mass-Test_P_00932_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.528, class ID : 0
# filename:malignant/Mass-Test_P_00942_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.680, class ID : 0
# filename:malignant/Mass-Test_P_00947_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.528, class ID : 0
# filename:malignant/Mass-Test_P_00951_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.697, class ID : 0
# filename:malignant/Mass-Test_P_00962_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.935, class ID : 0
# filename:malignant/Mass-Test_P_00969_LEFT_MLO_ROI_Arch_M_4.png .png,Original label:malignant, Prediction :benign, confidence : 0.677, class ID : 0
# filename:malignant/Mass-Test_P_00985_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.533, class ID : 0
# filename:malignant/Mass-Test_P_00987_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.754, class ID : 0
# filename:malignant/Mass-Test_P_01044_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.671, class ID : 0
# filename:malignant/Mass-Test_P_01068_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.558, class ID : 0
# filename:malignant/Mass-Test_P_01114_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.767, class ID : 0
# filename:malignant/Mass-Test_P_01213_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.603, class ID : 0
# filename:malignant/Mass-Test_P_01213_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.889, class ID : 0
# filename:malignant/Mass-Test_P_01277_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.570, class ID : 0
# filename:malignant/Mass-Test_P_01298_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.578, class ID : 0
# filename:malignant/Mass-Test_P_01298_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.956, class ID : 0
# filename:malignant/Mass-Test_P_01323_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.821, class ID : 0
# filename:malignant/Mass-Test_P_01347_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.532, class ID : 0
# filename:malignant/Mass-Test_P_01348_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.750, class ID : 0
# filename:malignant/Mass-Test_P_01489_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.860, class ID : 0
# filename:malignant/Mass-Test_P_01534_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.576, class ID : 0
# filename:malignant/Mass-Test_P_01534_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.716, class ID : 0
# filename:malignant/Mass-Test_P_01661_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.856, class ID : 0
# filename:malignant/Mass-Test_P_01661_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.710, class ID : 0
# filename:malignant/Mass-Test_P_01666_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.726, class ID : 0
# filename:malignant/Mass-Test_P_01719_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.818, class ID : 0
# filename:malignant/Mass-Test_P_01787_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.669, class ID : 0
# Accuracy 0.7188328912466844
# [[187  43]
#  [ 63  84]]
#               precision    recall  f1-score   support
#
#       benign       0.75      0.81      0.78       230
#    malignant       0.66      0.57      0.61       147
#
#     accuracy                           0.72       377
#    macro avg       0.70      0.69      0.70       377
# weighted avg       0.71      0.72      0.71       377
#
# No of errors = 106/377
# filename:benign/Mass-Test_P_00032_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.735, class ID : 1
# filename:benign/Mass-Test_P_00126_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.580, class ID : 1
# filename:benign/Mass-Test_P_00131_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.515, class ID : 1
# filename:benign/Mass-Test_P_00159_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.569, class ID : 1
# filename:benign/Mass-Test_P_00173_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.764, class ID : 1
# filename:benign/Mass-Test_P_00173_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.596, class ID : 1
# filename:benign/Mass-Test_P_00200_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.694, class ID : 1
# filename:benign/Mass-Test_P_00358_RIGHT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.712, class ID : 1
# filename:benign/Mass-Test_P_00359_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.638, class ID : 1
# filename:benign/Mass-Test_P_00369_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.527, class ID : 1
# filename:benign/Mass-Test_P_00405_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.560, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.625, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.795, class ID : 1
# filename:benign/Mass-Test_P_00482_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.602, class ID : 1
# filename:benign/Mass-Test_P_00494_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.766, class ID : 1
# filename:benign/Mass-Test_P_00587_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.935, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.676, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.542, class ID : 1
# filename:benign/Mass-Test_P_00639_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.574, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.672, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.744, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.611, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.607, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.536, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.750, class ID : 1
# filename:benign/Mass-Test_P_00922_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.925, class ID : 1
# filename:benign/Mass-Test_P_00951_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.700, class ID : 1
# filename:benign/Mass-Test_P_00966_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.752, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.549, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.575, class ID : 1
# filename:benign/Mass-Test_P_01145_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.696, class ID : 1
# filename:benign/Mass-Test_P_01254_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.513, class ID : 1
# filename:benign/Mass-Test_P_01322_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.616, class ID : 1
# filename:benign/Mass-Test_P_01395_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.615, class ID : 1
# filename:benign/Mass-Test_P_01416_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.857, class ID : 1
# filename:benign/Mass-Test_P_01512_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.622, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_MLO_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.621, class ID : 1
# filename:benign/Mass-Test_P_01623_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.748, class ID : 1
# filename:benign/Mass-Test_P_01645_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.517, class ID : 1
# filename:benign/Mass-Test_P_01684_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.696, class ID : 1
# filename:benign/Mass-Test_P_01697_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.932, class ID : 1
# filename:benign/Mass-Test_P_01726_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.538, class ID : 1
# filename:benign/Mass-Test_P_01825_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.774, class ID : 1
# filename:malignant/Mass-Test_P_00016_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.578, class ID : 0
# filename:malignant/Mass-Test_P_00017_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.829, class ID : 0
# filename:malignant/Mass-Test_P_00017_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.640, class ID : 0
# filename:malignant/Mass-Test_P_00066_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.538, class ID : 0
# filename:malignant/Mass-Test_P_00066_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.547, class ID : 0
# filename:malignant/Mass-Test_P_00116_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.682, class ID : 0
# filename:malignant/Mass-Test_P_00118_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.858, class ID : 0
# filename:malignant/Mass-Test_P_00147_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.585, class ID : 0
# filename:malignant/Mass-Test_P_00147_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.885, class ID : 0
# filename:malignant/Mass-Test_P_00194_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.907, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.772, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.788, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.607, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.882, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.660, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.955, class ID : 0
# filename:malignant/Mass-Test_P_00296_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.686, class ID : 0
# filename:malignant/Mass-Test_P_00324_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.687, class ID : 0
# filename:malignant/Mass-Test_P_00347_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.715, class ID : 0
# filename:malignant/Mass-Test_P_00481_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.619, class ID : 0
# filename:malignant/Mass-Test_P_00498_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.759, class ID : 0
# filename:malignant/Mass-Test_P_00514_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.716, class ID : 0
# filename:malignant/Mass-Test_P_00524_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.810, class ID : 0
# filename:malignant/Mass-Test_P_00576_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.748, class ID : 0
# filename:malignant/Mass-Test_P_00591_RIGHT_MLO_ROI_Mass_M_3.png .png,Original label:malignant, Prediction :benign, confidence : 0.956, class ID : 0
# filename:malignant/Mass-Test_P_00636_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.626, class ID : 0
# filename:malignant/Mass-Test_P_00641_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.574, class ID : 0
# filename:malignant/Mass-Test_P_00677_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.614, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.754, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.739, class ID : 0
# filename:malignant/Mass-Test_P_00758_LEFT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.723, class ID : 0
# filename:malignant/Mass-Test_P_00758_LEFT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.500, class ID : 0
# filename:malignant/Mass-Test_P_00773_LEFT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.823, class ID : 0
# filename:malignant/Mass-Test_P_00813_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.672, class ID : 0
# filename:malignant/Mass-Test_P_00932_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.563, class ID : 0
# filename:malignant/Mass-Test_P_00942_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.646, class ID : 0
# filename:malignant/Mass-Test_P_00947_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.559, class ID : 0
# filename:malignant/Mass-Test_P_00951_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.762, class ID : 0
# filename:malignant/Mass-Test_P_00962_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.922, class ID : 0
# filename:malignant/Mass-Test_P_00969_LEFT_MLO_ROI_Arch_M_4.png .png,Original label:malignant, Prediction :benign, confidence : 0.747, class ID : 0
# filename:malignant/Mass-Test_P_00987_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.718, class ID : 0
# filename:malignant/Mass-Test_P_01044_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.672, class ID : 0
# filename:malignant/Mass-Test_P_01068_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.563, class ID : 0
# filename:malignant/Mass-Test_P_01114_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.814, class ID : 0
# filename:malignant/Mass-Test_P_01140_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.511, class ID : 0
# filename:malignant/Mass-Test_P_01213_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.646, class ID : 0
# filename:malignant/Mass-Test_P_01213_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.906, class ID : 0
# filename:malignant/Mass-Test_P_01277_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.659, class ID : 0
# filename:malignant/Mass-Test_P_01298_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.586, class ID : 0
# filename:malignant/Mass-Test_P_01298_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.953, class ID : 0
# filename:malignant/Mass-Test_P_01323_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.835, class ID : 0
# filename:malignant/Mass-Test_P_01323_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.570, class ID : 0
# filename:malignant/Mass-Test_P_01347_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.601, class ID : 0
# filename:malignant/Mass-Test_P_01348_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.769, class ID : 0
# filename:malignant/Mass-Test_P_01489_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.838, class ID : 0
# filename:malignant/Mass-Test_P_01534_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.688, class ID : 0
# filename:malignant/Mass-Test_P_01534_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.755, class ID : 0
# filename:malignant/Mass-Test_P_01661_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.871, class ID : 0
# filename:malignant/Mass-Test_P_01661_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.710, class ID : 0
# filename:malignant/Mass-Test_P_01666_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.732, class ID : 0
# filename:malignant/Mass-Test_P_01719_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.746, class ID : 0
# filename:malignant/Mass-Test_P_01787_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.609, class ID : 0
# filename:malignant/Mass-Test_P_01815_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.527, class ID : 0
# Accuracy 0.6923076923076923
# [[171  59]
#  [ 57  90]]
#               precision    recall  f1-score   support
#
#       benign       0.75      0.74      0.75       230
#    malignant       0.60      0.61      0.61       147
#
#     accuracy                           0.69       377
#    macro avg       0.68      0.68      0.68       377
# weighted avg       0.69      0.69      0.69       377
#
# No of errors = 116/377
# filename:benign/Mass-Test_P_00032_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.807, class ID : 1
# filename:benign/Mass-Test_P_00032_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.537, class ID : 1
# filename:benign/Mass-Test_P_00126_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.690, class ID : 1
# filename:benign/Mass-Test_P_00126_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.536, class ID : 1
# filename:benign/Mass-Test_P_00131_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.637, class ID : 1
# filename:benign/Mass-Test_P_00159_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.622, class ID : 1
# filename:benign/Mass-Test_P_00173_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.847, class ID : 1
# filename:benign/Mass-Test_P_00173_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.644, class ID : 1
# filename:benign/Mass-Test_P_00200_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.768, class ID : 1
# filename:benign/Mass-Test_P_00238_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.511, class ID : 1
# filename:benign/Mass-Test_P_00238_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.544, class ID : 1
# filename:benign/Mass-Test_P_00358_RIGHT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.732, class ID : 1
# filename:benign/Mass-Test_P_00359_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.768, class ID : 1
# filename:benign/Mass-Test_P_00369_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.554, class ID : 1
# filename:benign/Mass-Test_P_00379_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.501, class ID : 1
# filename:benign/Mass-Test_P_00391_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.511, class ID : 1
# filename:benign/Mass-Test_P_00405_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.634, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.705, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.826, class ID : 1
# filename:benign/Mass-Test_P_00482_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.660, class ID : 1
# filename:benign/Mass-Test_P_00490_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.536, class ID : 1
# filename:benign/Mass-Test_P_00494_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.789, class ID : 1
# filename:benign/Mass-Test_P_00587_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.955, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.680, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.687, class ID : 1
# filename:benign/Mass-Test_P_00639_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.643, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.737, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.820, class ID : 1
# filename:benign/Mass-Test_P_00671_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.556, class ID : 1
# filename:benign/Mass-Test_P_00738_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.529, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.696, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.671, class ID : 1
# filename:benign/Mass-Test_P_00820_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.542, class ID : 1
# filename:benign/Mass-Test_P_00820_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.539, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.608, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.766, class ID : 1
# filename:benign/Mass-Test_P_00922_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.950, class ID : 1
# filename:benign/Mass-Test_P_00951_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.811, class ID : 1
# filename:benign/Mass-Test_P_00966_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.773, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.645, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.614, class ID : 1
# filename:benign/Mass-Test_P_01108_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.550, class ID : 1
# filename:benign/Mass-Test_P_01145_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.726, class ID : 1
# filename:benign/Mass-Test_P_01322_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.629, class ID : 1
# filename:benign/Mass-Test_P_01395_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.701, class ID : 1
# filename:benign/Mass-Test_P_01416_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.827, class ID : 1
# filename:benign/Mass-Test_P_01510_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.548, class ID : 1
# filename:benign/Mass-Test_P_01512_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.635, class ID : 1
# filename:benign/Mass-Test_P_01539_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.555, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.543, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_MLO_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.696, class ID : 1
# filename:benign/Mass-Test_P_01623_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.806, class ID : 1
# filename:benign/Mass-Test_P_01645_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.602, class ID : 1
# filename:benign/Mass-Test_P_01684_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.731, class ID : 1
# filename:benign/Mass-Test_P_01697_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.917, class ID : 1
# filename:benign/Mass-Test_P_01716_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.501, class ID : 1
# filename:benign/Mass-Test_P_01726_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.548, class ID : 1
# filename:benign/Mass-Test_P_01796_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.522, class ID : 1
# filename:benign/Mass-Test_P_01825_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.855, class ID : 1
# filename:malignant/Mass-Test_P_00017_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.835, class ID : 0
# filename:malignant/Mass-Test_P_00017_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.654, class ID : 0
# filename:malignant/Mass-Test_P_00116_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.785, class ID : 0
# filename:malignant/Mass-Test_P_00118_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.860, class ID : 0
# filename:malignant/Mass-Test_P_00147_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.571, class ID : 0
# filename:malignant/Mass-Test_P_00147_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.910, class ID : 0
# filename:malignant/Mass-Test_P_00194_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.891, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.762, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.715, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.557, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.835, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.560, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.927, class ID : 0
# filename:malignant/Mass-Test_P_00296_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.656, class ID : 0
# filename:malignant/Mass-Test_P_00324_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.713, class ID : 0
# filename:malignant/Mass-Test_P_00347_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.699, class ID : 0
# filename:malignant/Mass-Test_P_00481_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.611, class ID : 0
# filename:malignant/Mass-Test_P_00498_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.715, class ID : 0
# filename:malignant/Mass-Test_P_00514_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.650, class ID : 0
# filename:malignant/Mass-Test_P_00524_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.773, class ID : 0
# filename:malignant/Mass-Test_P_00576_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.632, class ID : 0
# filename:malignant/Mass-Test_P_00591_RIGHT_MLO_ROI_Mass_M_3.png .png,Original label:malignant, Prediction :benign, confidence : 0.963, class ID : 0
# filename:malignant/Mass-Test_P_00636_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.541, class ID : 0
# filename:malignant/Mass-Test_P_00641_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.564, class ID : 0
# filename:malignant/Mass-Test_P_00677_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.587, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.732, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.721, class ID : 0
# filename:malignant/Mass-Test_P_00758_LEFT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.716, class ID : 0
# filename:malignant/Mass-Test_P_00773_LEFT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.767, class ID : 0
# filename:malignant/Mass-Test_P_00813_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.675, class ID : 0
# filename:malignant/Mass-Test_P_00820_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.741, class ID : 0
# filename:malignant/Mass-Test_P_00932_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.531, class ID : 0
# filename:malignant/Mass-Test_P_00942_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.649, class ID : 0
# filename:malignant/Mass-Test_P_00951_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.687, class ID : 0
# filename:malignant/Mass-Test_P_00962_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.911, class ID : 0
# filename:malignant/Mass-Test_P_00969_LEFT_MLO_ROI_Arch_M_4.png .png,Original label:malignant, Prediction :benign, confidence : 0.617, class ID : 0
# filename:malignant/Mass-Test_P_00987_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.674, class ID : 0
# filename:malignant/Mass-Test_P_01044_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.624, class ID : 0
# filename:malignant/Mass-Test_P_01068_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.589, class ID : 0
# filename:malignant/Mass-Test_P_01114_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.770, class ID : 0
# ...
# filename:benign/Mass-Test_P_00173_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.639, class ID : 1
# filename:benign/Mass-Test_P_00200_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.744, class ID : 1
# filename:benign/Mass-Test_P_00358_RIGHT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.740, class ID : 1
# filename:benign/Mass-Test_P_00359_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.731, class ID : 1
# filename:benign/Mass-Test_P_00369_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.580, class ID : 1
# filename:benign/Mass-Test_P_00391_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.528, class ID : 1
# filename:benign/Mass-Test_P_00405_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.646, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.660, class ID : 1
# filename:benign/Mass-Test_P_00429_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.835, class ID : 1
# filename:benign/Mass-Test_P_00470_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.514, class ID : 1
# filename:benign/Mass-Test_P_00482_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.591, class ID : 1
# filename:benign/Mass-Test_P_00490_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.501, class ID : 1
# filename:benign/Mass-Test_P_00494_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.836, class ID : 1
# filename:benign/Mass-Test_P_00587_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.956, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.742, class ID : 1
# filename:benign/Mass-Test_P_00629_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.537, class ID : 1
# filename:benign/Mass-Test_P_00639_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.670, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.733, class ID : 1
# filename:benign/Mass-Test_P_00662_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.818, class ID : 1
# filename:benign/Mass-Test_P_00671_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.565, class ID : 1
# filename:benign/Mass-Test_P_00738_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.539, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.766, class ID : 1
# filename:benign/Mass-Test_P_00766_LEFT_MLO_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.580, class ID : 1
# filename:benign/Mass-Test_P_00820_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.534, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.587, class ID : 1
# filename:benign/Mass-Test_P_00882_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.792, class ID : 1
# filename:benign/Mass-Test_P_00922_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.934, class ID : 1
# filename:benign/Mass-Test_P_00951_LEFT_CC_ROI_Arch_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.693, class ID : 1
# filename:benign/Mass-Test_P_00966_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.792, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.614, class ID : 1
# filename:benign/Mass-Test_P_00979_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.663, class ID : 1
# filename:benign/Mass-Test_P_01108_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.590, class ID : 1
# filename:benign/Mass-Test_P_01145_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.781, class ID : 1
# filename:benign/Mass-Test_P_01254_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.503, class ID : 1
# filename:benign/Mass-Test_P_01322_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.674, class ID : 1
# filename:benign/Mass-Test_P_01395_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.705, class ID : 1
# filename:benign/Mass-Test_P_01416_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.840, class ID : 1
# filename:benign/Mass-Test_P_01510_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.538, class ID : 1
# filename:benign/Mass-Test_P_01512_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.685, class ID : 1
# filename:benign/Mass-Test_P_01539_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.569, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_CC_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.535, class ID : 1
# filename:benign/Mass-Test_P_01566_RIGHT_MLO_ROI_Mass_B_2.png .png,Original label:benign, Prediction :malignant, confidence : 0.713, class ID : 1
# filename:benign/Mass-Test_P_01623_RIGHT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.755, class ID : 1
# filename:benign/Mass-Test_P_01645_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.564, class ID : 1
# filename:benign/Mass-Test_P_01684_LEFT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.711, class ID : 1
# filename:benign/Mass-Test_P_01697_LEFT_MLO_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.933, class ID : 1
# filename:benign/Mass-Test_P_01726_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.541, class ID : 1
# filename:benign/Mass-Test_P_01825_RIGHT_CC_ROI_Mass_B_1.png .png,Original label:benign, Prediction :malignant, confidence : 0.840, class ID : 1
# filename:malignant/Mass-Test_P_00016_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.518, class ID : 0
# filename:malignant/Mass-Test_P_00017_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.817, class ID : 0
# filename:malignant/Mass-Test_P_00017_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.613, class ID : 0
# filename:malignant/Mass-Test_P_00066_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.518, class ID : 0
# filename:malignant/Mass-Test_P_00116_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.646, class ID : 0
# filename:malignant/Mass-Test_P_00118_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.785, class ID : 0
# filename:malignant/Mass-Test_P_00147_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.927, class ID : 0
# filename:malignant/Mass-Test_P_00194_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.864, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.699, class ID : 0
# filename:malignant/Mass-Test_P_00198_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.733, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.684, class ID : 0
# filename:malignant/Mass-Test_P_00202_RIGHT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.902, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.610, class ID : 0
# filename:malignant/Mass-Test_P_00212_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.949, class ID : 0
# filename:malignant/Mass-Test_P_00296_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.676, class ID : 0
# filename:malignant/Mass-Test_P_00324_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.636, class ID : 0
# filename:malignant/Mass-Test_P_00347_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.699, class ID : 0
# filename:malignant/Mass-Test_P_00481_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.592, class ID : 0
# filename:malignant/Mass-Test_P_00498_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.743, class ID : 0
# filename:malignant/Mass-Test_P_00514_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.632, class ID : 0
# filename:malignant/Mass-Test_P_00524_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.765, class ID : 0
# filename:malignant/Mass-Test_P_00576_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.681, class ID : 0
# filename:malignant/Mass-Test_P_00591_RIGHT_MLO_ROI_Mass_M_3.png .png,Original label:malignant, Prediction :benign, confidence : 0.958, class ID : 0
# filename:malignant/Mass-Test_P_00636_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.579, class ID : 0
# filename:malignant/Mass-Test_P_00641_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.630, class ID : 0
# filename:malignant/Mass-Test_P_00677_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.527, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.763, class ID : 0
# filename:malignant/Mass-Test_P_00741_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.742, class ID : 0
# filename:malignant/Mass-Test_P_00758_LEFT_CC_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.690, class ID : 0
# filename:malignant/Mass-Test_P_00773_LEFT_MLO_ROI_Arch_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.753, class ID : 0
# filename:malignant/Mass-Test_P_00813_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.604, class ID : 0
# filename:malignant/Mass-Test_P_00820_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.642, class ID : 0
# filename:malignant/Mass-Test_P_00932_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.521, class ID : 0
# filename:malignant/Mass-Test_P_00942_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.580, class ID : 0
# filename:malignant/Mass-Test_P_00947_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.508, class ID : 0
# filename:malignant/Mass-Test_P_00951_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.699, class ID : 0
# filename:malignant/Mass-Test_P_00962_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.929, class ID : 0
# filename:malignant/Mass-Test_P_00969_LEFT_MLO_ROI_Arch_M_4.png .png,Original label:malignant, Prediction :benign, confidence : 0.665, class ID : 0
# filename:malignant/Mass-Test_P_00985_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.517, class ID : 0
# filename:malignant/Mass-Test_P_00987_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.737, class ID : 0
# filename:malignant/Mass-Test_P_01044_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.659, class ID : 0
# filename:malignant/Mass-Test_P_01068_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.529, class ID : 0
# filename:malignant/Mass-Test_P_01114_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.728, class ID : 0
# filename:malignant/Mass-Test_P_01167_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.511, class ID : 0
# filename:malignant/Mass-Test_P_01213_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.558, class ID : 0
# filename:malignant/Mass-Test_P_01213_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.873, class ID : 0
# filename:malignant/Mass-Test_P_01277_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.522, class ID : 0
# filename:malignant/Mass-Test_P_01298_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.590, class ID : 0
# filename:malignant/Mass-Test_P_01298_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.949, class ID : 0
# filename:malignant/Mass-Test_P_01323_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.794, class ID : 0
# filename:malignant/Mass-Test_P_01323_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.507, class ID : 0
# filename:malignant/Mass-Test_P_01347_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.529, class ID : 0
# filename:malignant/Mass-Test_P_01348_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.720, class ID : 0
# filename:malignant/Mass-Test_P_01489_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.847, class ID : 0
# filename:malignant/Mass-Test_P_01534_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.584, class ID : 0
# filename:malignant/Mass-Test_P_01534_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.733, class ID : 0
# filename:malignant/Mass-Test_P_01661_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.872, class ID : 0
# filename:malignant/Mass-Test_P_01661_LEFT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.684, class ID : 0
# filename:malignant/Mass-Test_P_01666_RIGHT_MLO_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.700, class ID : 0
# filename:malignant/Mass-Test_P_01719_RIGHT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.811, class ID : 0
# filename:malignant/Mass-Test_P_01787_LEFT_CC_ROI_Mass_M_1.png .png,Original label:malignant, Prediction :benign, confidence : 0.529, class ID : 0

# %%
# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		yhat = model.predict(inputX, verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = yhat
		else:
			stackX = dstack((stackX, yhat))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# %%
# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# fit standalone model
	model = LogisticRegression()
	model.fit(stackedX, inputy)
	return model

# %%
# fit stacked model using the ensemble
model = fit_stacked_model(members, testX, testy)

# %%
# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	yhat = model.predict(stackedX)
	return yhat

# %%
# evaluate model on test set as stacked ensemble

yhat = stacked_prediction(members, model, testX)
acc = accuracy_score(testy, yhat)
print('Stacked Test Accuracy: %.3f' % acc)
# Out:
# Stacked Test Accuracy: 0.762
